# %% [markdown]
# <a href="https://colab.research.google.com/github/mumtahinamomo/data-economics/blob/main/dataecon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone -b dc-debug https://github.com/mumtahinamomo/data-economics.git

# %%
# %cd data-economics
# Out:
# /content/data-economics

# %%
# !git branch
# Out:
# * dc-debug

# %%
# !python graph.py
# Out:
# Figure(640x480)

# %%
# !pip install pandas numpy torch transformers

# %%
# %cd /content/data-economics
# Out:
# /content/data-economics

# %%
# !cd /content/data-economics/marginal_value && python run.py
# Out:
# Doing n=100 seed=0
# n=100 seed=0 train_loss=6.0015 train_acc=0.1673 val_loss=7.8893 val_acc=0.1733
# Doing n=100 seed=1
# n=100 seed=1 train_loss=5.8041 train_acc=0.1680 val_loss=8.0456 val_acc=0.1540
# Doing n=100 seed=2
# n=100 seed=2 train_loss=5.7803 train_acc=0.1780 val_loss=7.7448 val_acc=0.1793
# Doing n=100 seed=3
# n=100 seed=3 train_loss=5.8171 train_acc=0.1647 val_loss=7.9749 val_acc=0.1747
# Doing n=100 seed=4
# n=100 seed=4 train_loss=5.8884 train_acc=0.1720 val_loss=8.1095 val_acc=0.1620
# Doing n=200 seed=0
# n=200 seed=0 train_loss=6.2347 train_acc=0.1697 val_loss=7.9893 val_acc=0.1690
# Doing n=200 seed=1
# n=200 seed=1 train_loss=6.0682 train_acc=0.1697 val_loss=7.9530 val_acc=0.1817
# Doing n=200 seed=2
# n=200 seed=2 train_loss=6.0404 train_acc=0.1673 val_loss=7.8758 val_acc=0.1750
# Doing n=200 seed=3
# n=200 seed=3 train_loss=6.0868 train_acc=0.1717 val_loss=7.9080 val_acc=0.1843
# Doing n=200 seed=4
# ...

# %%
# !cd /content/data-economics/marginal_value && python graph.py
# Out:
# Figure(640x480)

# %%
from IPython.display import Image
Image("/content/data-economics/marginal_value/graphplot.png")

# %%
# !cd /content/data-economics/marginal_value && python marginalvalue.py
# Out:
# Resolving data files: 100% 80/80 [00:00<00:00, 395222.99it/s]
# ...
# Resolving data files: 100% 80/80 [00:00<00:00, 402331.32it/s]
